# %% [markdown]
# # Completa las celdas vacías implementando la funcionalidad pedida

# %% [markdown]
# ## 1) Escrible un código que imprima "Hola Mundo"

# %% [markdown]
# ## 2) Creación y uso de variables simples
# 1. Crea una variable numérica con valor del día de tu cumpleaños
#
# 2. Crea una variable de tipo cadena de caracteres con valor con las iniciales de tu nombre y apellidos
#
# 3. Imprime el valor y el tipo de cada una de ellas
#
# 4. Imprime un string que sea resultado de unir ambas variables con una "_" de por medio, no olvides realizar los casting que sean necesarios para que la concatenación pueda funcionar, la salida tendría que quedar estilo "00_abcd"
#
# 5. Luego elimina ambas variables

# %% [markdown]
# ## 3) Trabajando con números
# 1. Crea dos variables, una llamanda num_1 con valor 7 y otra llamada num_2 con valor 12.5
#
# 2. Calcula lo siguiente:
#
# >((num_1 - num_2)\*\*num_1)\*0.75
#
# 3. Almacena el resultado de la operación anterior en una variable llamada num_res
#
# 4. Calcula el resultado de dividir el **valor absoluto** de num_res entre 12.22 y actualiza el valor de num_res con este nuevo resultado
#
# 5. Redondea el número num_res a 2 cifras decimales
#
# 6. Crea una nueva variable llamada num_res_int que contenga el **suelo** entero de valor actual de num_res

# %% [markdown]
# ## 4) Trabajando con strings

# %% [markdown]
# Crea una variable llamada string_1 que contenga el texto:
#
# <i>"La astrofísica es el desarrollo y estudio de la física aplicada a la astronomía.<br>
# Estudia las estrellas, los planetas, las galaxias, los agujeros negros y demás objetos astronómicos como cuerpos de la física, incluyendo su composición, estructura y evolución. <br>
# La astrofísica emplea la física para explicar las propiedades y fenómenos de los cuerpos estelares a través de sus leyes, fórmulas y magnitudes."</I>
#
# Recuerda introducir el caracter especial correspondiente para que se respeten los saltos de línea especificados
#
# Luego haz lo siguiente:
# 1. Imprime el texto completo
# 2. Imprime la longitud del texto
# 3. Imprime los caracteres con índices del 3 al 14
# 4. Imprime los caracteres desde "Estudia las estrellas" hasta el final
# 5. Imprime si la secuencia de caracteres "WAF" se encuentra o no en el texto (True o False)
# 6. Imprime cuantas veces se menciona física en el texto.
# 7. Imprime una versión del string con todos sus caracteres en minúscula

# %% [markdown]
# ## 5) Trabajando con Booleanos
# 1. Crea dos variables, una llamda var_1 con valor True y otra llamada var_2 con valor False. Utiliza las variables para ver los resultados.
#
# 2. ¿Cuál es el resultado de hacer un "and" ente ambas?
#
# 3. ¿Cuál es el resultado de hacer un "or" ente ambas?
#
# 4. ¿Cuál es el resultado de hacer un "not" de var_2?
#
# Bonus díficil:
# Utilizando las operaciones booleanas intenta hacer un or exclusivo. Es decir, que solo sea verdadero si var_1 es verdadero y var_2 es falso o var_2 es verdadera y var_1 falso.

# %% [markdown]
# ## 6) Trabajando con listas
# 0. Crea estas dos listas:
#
# ><li>list_1 = ["a", "b", "c"]
#
# ><li>list_2 = [3, 10, 2, 1]
# <br><br>
#
# 1. Imprime el primer elemento de la lista list_1
#
# 2. Imprime el tercer elemento comenzando por la derecha de list_2
#
# 3. Imprime el número que tenga el *valor máximo* en list_2 (Tiene que ser automático, no pongas tu el valor)
#
# 4. Crea una lista llamada list_cat que sea la concatenación de las dos listas
#
# 5. Añade a list_cat un nuevo elemento con valor 12.5
#
# 6. Imprime la longitud de list_cat
#
# 7. Remplaza el **elemento** número 3 de list_cat por el valor "x"
#
# 8. Elimina el item con **índice** 2 de list_cat
#
# 9. Reordena los elementos de la lista para que tengan el orden inverso del actual
#
# 10. Crea una nueva variable que se llame list_1_sorted con la lista 2 ordenada

# %% [markdown]
# ## 7) Trabajando con tuplas
#
# Intenta hacer todos los pasos anteriores pero usando tuplas, algunos de ellos fallarán, explica brevemente por qué ocurre esto y cuál es la utilidad de este comportamiento.

# %%
# En esta celda realiza los pasos anteriores (puedes usar más celdas si lo quieres dejar más ordenado)

# %%
# Para la explicación, reemplaza el string con la respuesta a la pregunta del enunciado
# que resuma que ocurre en los puntos que falló y que utilidad puede tener este comportamiento
tu_explicacion = "Sin responder"
print(tu_explicacion)

# %% [markdown]
# ## 8) Trabajando con diccionarios
# 1. Crea un diccionario vacío y rellénalo con estos datos (entendiéndose como pares clave-valor):
# ```
# "38195348N": "Pepin Pérez"
# "26173220P": "Juanito Martínez"
# "83740289Q": "Adolfo Rodríguez"
# "91588605M": "Roberto García"
# ```
#
# 2. Consulta el diccionario, ¿Cuál es el nombre de la persona con DNI "26173220P"?
#
# 3. Cambia el nombre asociado a la clave "91588605M" por "Roberto Martínez"
#
# 4. Elimina la entrada correspondiente a la clave "26173220P"
#
# 5. Agrega una nueva persona en tu diccionario
#
# 6. Imprime la longitud del diccionario
#
# 7. Imprime si la clave "99114051J" está o no en el diccionario (True o False)
#
# 8. Imprime las claves del diccionario
#
# 9. Imprime los valores del diccionario
#
# 10. Haz una copia del diccionario en una nueva variable de manera que si se modifican los valores en esta nueva variable no se modifique la original. Comprueba que modificando uno no se modifique el otro

# %% [markdown]
# ## 9) Trabajando con conjuntos
# 1. Crea una lista con los siguientes valores
# ```
# [1,2,2,2,3,2,3,5,1]
# ```
#
# 2. Convierte esta lista a otra lista que no contenga elementos repetidos
#
# 3. Crea los dos siguientes conjuntos:
# ```
# conj_1 = {1,2,3,4,5}
# conj_2 = {3,4,5,6,7}
# ```
# 4. Comprueba si el elemento 9 está en el conjunto 1
#
# 5. ¿Son conjuntos disjuntos?
#
# 6. ¿Es conj_1 un subconjunto de conj_2?
#
# 7. Calcula los elementos que estén en conj_1 pero no en conj_2
#
# 8. Calcula los elementos comunes a ambos conjuntos

# %% [markdown]
# ## 9) Trabajando con if, if-else, if-elif
# Tenemos dos variables, les asignamos inicialmente estos valores:
# <li>var_1 = [0, 1]
# <li>var_2 = [0,1,2,3,4,5]
# <br><br>
#
# Implementar la siguiente lógica:
# <li>Si la longitud de var_1 es mayor que la de var_2 imprimimos "var_1 tiene longitud mayor que var_2"
# <li>Si la condición anterior no se cumple y la longitud de var_1 es igual que la de var_2 imprimimos "var_1 tiene longitud igual que var_2"
# <li> Si la condición anterior no se cumple y si el elemento en el índice 0 de var_1 es igual al elemento del índice 0 de var_2 imprimimos "Ambas listas comienzan por el mismo valor"
# <li>Si no se cumple nada de lo anterior imprimimos "No se cumple ninguna de las condiciones"
# <br><br>
# Ahora modifica la estructura anterior y añade la siguiente lógica:
# <li> Si el elemento en el índice 0 de var_1 es igual al elemento del índice 0 de var_2 y el elemento en el índice 1 de var_1 es igual al elemento del índice 1 de var_2 imprimimos "Ambas listas comienzan por los dos mismos valores"
# <li> Si la condición anterior no se cumple, imprimimos: "Al menos uno de los dos primero valores de ambas listas son diferentes"
# <br><br>

# %% [markdown]
# ##### 2ª Parte
# Es importante probar lo que se programa, por lo que hay que asegurarse que se cumplen todos los posibles caminos lógicos que hemos establecido en nuestro código. <br>
# En esta segunda parte inventate otras dos listas var_1 y var_2 que cumpla/n otro/s condicional/es que las listas originales no cubrian.

# %% [markdown]
# ## 11) Trabajando con for y while
#
# Tenemos las siguientes listas:
# <li>char_list = ["o","y", "t", "h", "n","p"]
# <li>num_list = [5, 1, 2, 3, 0,-2]
# <br><br>
#
# Realizar un bucle for que recorra num_list e imprima sus valores y además imprima el caracter con el índice correspondiente a ese número.

# %% [markdown]
# Crear un bucle while que mientras el máximo valor de num_list sea menor a 10 siga iterando, pero que en cada iteración añada un elemento a la lista cuyo valor sea una unidad mayor al valor máximo que haya en ese momento en num_list. Por ejemplo, el primer valor que se añadiría sería 6, el siguiente 7 y así sucesivamente:

# %% [markdown]
# ## 12) Problema final
# Contexto:
#
# Estás trabajando brindando apoyo en el desarrollo de un subsistema informático de una empresa de venta de seguros. Tu responsable necesita que hagas un programa sencillo que transforme una lista de coberturas en una cadena de texto para mostrársela al usuario.
#
# Requisitos:
#
# - Omitir campos con valor None: Si algún campo en los datos de la cobertura tiene el valor None, debes omitir esa parte en el texto resultante.
# - Valor especial para LIMMAXRESP: Si el valor de "LIMMAXRESP" es igual a "1", debes reemplazarlo por "el valor establecido por la ley".
#
#
# Datos del ejemplo proporcionado por tu responsable:
# ```
# listado_coberturas = [
#     {"cobertura_1": {
#         "COBERTURA": "Robo",
#         "LIMMAXRESP": "5000",
#         "PRIMAS": "200"
#     }},
#     {"cobertura_2": {
#         "COBERTURA": "Incendio",
#         "LIMMAXRESP": "1",
#         "PRIMAS": None
#     }}
# ]
# ```
#
# Formato esperado del texto resultante a partir de los datos anteriores:
# ```
# Las coberturas disponibles para el pack elegido son las siguientes:
# La cobertura nº1 cubre "Robo" con un límite máximo de 5000€ con una prima de 200€.
# La cobertura nº2 cubre "Incendio" con un límite máximo del valor establecido por la ley.
# ```

# %% [markdown]
# #### 2ª Parte
# En la primera parte habrás probado con el propio ejemplo, vamos a asegurarnos que lo hemos hecho bien y hemos cubierto todos los casos.
# Ejecuta el mismo código pero esta vez sobre este listado_coberturas:
# ```
# listado_coberturas = [
#     {"cobertura_1": {
#         "COBERTURA": "Daños a terceros",
#         "LIMMAXRESP": "1000",
#         "PRIMAS": None
#     }},
#     {"cobertura_2": {
#         "COBERTURA": "Incendio",
#         "LIMMAXRESP": "1000",
#         "PRIMAS": 200
#     }},
#     {"cobertura_3": {
#         "COBERTURA": "Defensa jurídica",
#         "LIMMAXRESP": None,
#         "PRIMAS": 400
#     }},
#     {"cobertura_42": {
#         "COBERTURA": None,
#         "LIMMAXRESP": 1,
#         "PRIMAS": 1
#     }}
# ]
# ```

# %% [markdown]
# #### 3ª Parte
# Y si no te mandan nada?
# ```
# listado_coberturas = []
# ó
# listado_coberturas = None
# ```
